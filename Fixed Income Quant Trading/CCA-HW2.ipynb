# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from statsmodels.tsa.api import VAR
from sklearn.decomposition import PCA
import statsmodels.tsa.stattools
from arch.unitroot import ADF
import statsmodels.api as sm
# %matplotlib inline
# Out:
# /Users/qichaohuang/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
#importing data and calculating daily differences
di = "/users/Edith/Python/Data/"
data = pd.read_excel('CMT-all.xlsx', index_col = 0)

sample_1=data.ix['2013-01-01':'2014-12-31',['3M','2Y','5Y','7Y','10Y','30Y']]
sample_2=data.ix['2015-01-01':'2016-12-31',['3M','2Y','5Y','7Y','10Y','30Y']]

# %%
legs = ['2Y', '10Y']
belly = '5Y'
flylist = [legs[0],belly, legs[1]]

sample_1_fly=data.ix['2013-01-01':'2014-12-31',flylist]
sample_2_fly=data.ix['2015-01-01':'2016-12-31',flylist]

sample_1_rtns= sample_1.diff()
sample_2_rtns= sample_2.diff()
sample_q_rtns= sample_2.diff()

plt.figure(figsize=(20,10))
plt.plot(sample_1_fly,linewidth=3)
plt.show()
plt.figure(figsize=(20,10))
plt.plot(sample_2_fly,linewidth=3)
plt.show()

# %%
def PCA_simple(data_set):
    c = data_set.cov()
    val, vec = np.linalg.eig(c)
    return pd.DataFrame(vec)

# %%
def Factor_Neutral_Weights(df, legs_index, target_index):
    n = len(legs_index)
    x = df.ix[legs_index,range(n)]
    y = df.ix[target_index,range(n)]
    x = x.as_matrix()
    y = y.as_matrix()
    z=np.linalg.inv(x)
    w = np.matmul(y,z)
    if sum(w) < 0:
        w = [ww*(-1) for ww in w]
    return w

# %%
def ols_weights(df, x_index, y_index):
    x = df[x_index].as_matrix()
    y = df[y_index].as_matrix()
    x_I = sm.add_constant(x)
    l = sm.OLS(y,x_I).fit()
    n = len(x_index)
    return l.params[1:(n+1)]

# %%
v = PCA_simple(sample_1)
w_pca_lev = Factor_Neutral_Weights(v,[1,4],2) 
print (w_pca_lev)
v = PCA_simple(sample_1_rtns)
w_pca_ret = Factor_Neutral_Weights(v,[1,4],2) 
print (w_pca_ret)
# Out:
# [ 2.03850473  0.60292276]
# [ 1.13693977  0.54779512]

# %%
w_ols = ols_weights(sample_1_fly,legs,[belly])
print (w_ols)
# Out:
# [ 1.83432697  0.62525271]

# %%
def CCA_Chou_Ng(data_set):
    
    df_lag = data_set.shift(1).dropna()
    df = data_set.drop(data_set.index[0]).dropna()
    n = len(data_set.columns)
    
    #X(t) ~ M_! + X(t-1)
    X = df_lag.as_matrix()
    X_I = sm.add_constant(X)
    Y = df.as_matrix()
    l1 = sm.OLS(Y,X_I).fit()
    B=l1.params[1:(n+1)]
    
    #X(t-1) ~ M_2 + X(t)
    Y_I = sm.add_constant(X)
    l2 = sm.OLS(X,Y_I).fit()
    A=l2.params[1:(n+1)]
    C = np.dot(A,B)
    eig_val, eig_vec = np.linalg.eig(C)
    return eig_val, eig_vec, C

# %%
df = sample_1_fly
print df
n = len(df.columns)
val, vec, C = CCA_Chou_Ng(df)
print val
vec = pd.DataFrame(vec)
vec = vec.rename(columns=lambda x: n-x-1, inplace=False)
print (vec)
w = vec[2].values
print w
w_cca_cn = [-w[0]/w[1],-w[2]/w[1]]
print (w_cca_cn)
# Out:
#               2Y    5Y   10Y
# Date
# 2013-01-02  0.27  0.76  1.86
# 2013-01-03  0.27  0.81  1.92
# 2013-01-04  0.27  0.82  1.93
# 2013-01-07  0.27  0.82  1.92
# 2013-01-08  0.25  0.79  1.89
# 2013-01-09  0.24  0.77  1.88
# 2013-01-10  0.26  0.80  1.91
# 2013-01-11  0.26  0.78  1.89
# 2013-01-14  0.26  0.78  1.89
# 2013-01-15  0.26  0.75  1.86
# 2013-01-16  0.26  0.75  1.84
# 2013-01-17  0.28  0.79  1.89
# 2013-01-18  0.26  0.77  1.87
# 2013-01-22  0.26  0.76  1.86
# 2013-01-23  0.26  0.76  1.86
# 2013-01-24  0.23  0.78  1.88
# 2013-01-25  0.28  0.87  1.98
# 2013-01-28  0.29  0.89  2.00
# 2013-01-29  0.30  0.90  2.03
# 2013-01-30  0.27  0.88  2.03
# 2013-01-31  0.27  0.88  2.02
# 2013-02-01  0.27  0.88  2.04
# 2013-02-04  0.25  0.85  2.00
# 2013-02-05  0.27  0.88  2.04
# 2013-02-06  0.27  0.84  2.00
# 2013-02-07  0.25  0.83  1.99
# 2013-02-08  0.25  0.84  1.99
# 2013-02-11  0.27  0.85  1.99
# 2013-02-12  0.29  0.88  2.02
# 2013-02-13  0.29  0.92  2.05
# ...          ...   ...   ...
# 2014-11-18  0.53  1.63  2.32
# 2014-11-19  0.54  1.66  2.36
# 2014-11-20  0.53  1.64  2.34
# 2014-11-21  0.53  1.63  2.31
# 2014-11-24  0.53  1.62  2.30
# 2014-11-25  0.51  1.58  2.27
# 2014-11-26  0.53  1.56  2.24
# 2014-11-28  0.47  1.49  2.18
# 2014-12-01  0.49  1.52  2.22
# 2014-12-02  0.55  1.59  2.28
# 2014-12-03  0.57  1.61  2.29
# 2014-12-04  0.55  1.59  2.25
# 2014-12-05  0.65  1.69  2.31
# 2014-12-08  0.64  1.67  2.26
# 2014-12-09  0.64  1.63  2.22
# 2014-12-10  0.59  1.58  2.18
# 2014-12-11  0.62  1.62  2.19
# 2014-12-12  0.56  1.53  2.10
# 2014-12-15  0.60  1.58  2.12
# 2014-12-16  0.58  1.53  2.07
# 2014-12-17  0.62  1.61  2.14
# 2014-12-18  0.67  1.68  2.22
# 2014-12-19  0.67  1.66  2.17
# 2014-12-22  0.71  1.67  2.17
# 2014-12-23  0.73  1.76  2.26
# 2014-12-24  0.73  1.76  2.27
# 2014-12-26  0.73  1.75  2.25
# 2014-12-29  0.72  1.72  2.22
# 2014-12-30  0.69  1.68  2.20
# 2014-12-31  0.67  1.65  2.17
#
# [500 rows x 3 columns]
# [ 0.89797131  0.99988428  0.99253083]
#           2         1         0
# 0  0.859852  0.282033 -0.576731
# 1 -0.431059 -0.765590  0.740764
# 2  0.273574  0.578212 -0.344456
# [ 0.85985188 -0.43105889  0.27357445]
# [1.9947434220096747, 0.63465678490444688]

# %%
def fly(df,legs,w):
    return df[legs[0]]*w[0]-df[legs[1]]+df[legs[2]]*w[1]

# %%
w = {'Equal':[1,1],
     'PCA Diffs': w_pca_ret, 
     'PCA Level': w_pca_lev, 
     'OLS Level': w_ols,
     'Coint': w_cca_cn }

legs = flylist
for k in w.keys():
    print ('Weights: ',w[k])
    fly_1 = fly(sample_1_fly,legs,w[k]) 
    fly_2 = fly(sample_2_fly,legs,w[k]) 

    adfuller_fly_1 = ADF(fly_1,lags = 1)
    print('ADF Test Summary, Sample 1: '+k, adfuller_fly_1)
    adfuller_fly_2 = ADF(fly_2, lags = 1)
    print('\n \n ADF Test Summary, Sample 2: '+k, adfuller_fly_2)
# Out:
# ('Weights: ', array([ 1.83432697,  0.62525271]))
# ('ADF Test Summary, Sample 1: OLS Level', <class 'arch.unitroot.unitroot.ADF'>
# """
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -3.759
# P-value                         0.003
# Lags                                1
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.44 (1%), -2.87 (5%), -2.57 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
# """)
# ('\n \n ADF Test Summary, Sample 2: OLS Level', <class 'arch.unitroot.unitroot.ADF'>
# """
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -0.961
# P-value                         0.767
# Lags                                1
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.44 (1%), -2.87 (5%), -2.57 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
# """)
# ('Weights: ', array([ 2.03850473,  0.60292276]))
# ('ADF Test Summary, Sample 1: PCA Level', <class 'arch.unitroot.unitroot.ADF'>
# """
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -3.857
# P-value                         0.002
# Lags                                1
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.44 (1%), -2.87 (5%), -2.57 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
# """)
# ('\n \n ADF Test Summary, Sample 2: PCA Level', <class 'arch.unitroot.unitroot.ADF'>
# """
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -0.962
# P-value                         0.767
# Lags                                1
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.44 (1%), -2.87 (5%), -2.57 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
# """)
# ('Weights: ', [1.9947434220096745, 0.6346567849044632])
# ('ADF Test Summary, Sample 1: Coint', <class 'arch.unitroot.unitroot.ADF'>
# """
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -3.976
# P-value                         0.002
# Lags                                1
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.44 (1%), -2.87 (5%), -2.57 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
# """)
# ('\n \n ADF Test Summary, Sample 2: Coint', <class 'arch.unitroot.unitroot.ADF'>
# """
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -0.978
# P-value                         0.761
# Lags                                1
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.44 (1%), -2.87 (5%), -2.57 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
# """)
# ('Weights: ', [1, 1])
# ('ADF Test Summary, Sample 1: Equal', <class 'arch.unitroot.unitroot.ADF'>
# """
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -1.235
# P-value                         0.659
# Lags                                1
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.44 (1%), -2.87 (5%), -2.57 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
# """)
# ('\n \n ADF Test Summary, Sample 2: Equal', <class 'arch.unitroot.unitroot.ADF'>
# """
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -1.340
# P-value                         0.611
# Lags                                1
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.44 (1%), -2.87 (5%), -2.57 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
# """)
# ('Weights: ', array([ 1.13693977,  0.54779512]))
# ('ADF Test Summary, Sample 1: PCA Diffs', <class 'arch.unitroot.unitroot.ADF'>
# """
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -1.704
# P-value                         0.429
# Lags                                1
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.44 (1%), -2.87 (5%), -2.57 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
# """)
# ('\n \n ADF Test Summary, Sample 2: PCA Diffs', <class 'arch.unitroot.unitroot.ADF'>
# """
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -0.986
# P-value                         0.758
# Lags                                1
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.44 (1%), -2.87 (5%), -2.57 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
# """)
